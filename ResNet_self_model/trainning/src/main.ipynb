# %%
from processor import Processor

processor = Processor(USE_CUDA=True, parameter=[3, 2, 64, "ResNet 18"], learning_rate=0.0001, echos=30)

processor.processing(times=1)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch 1 | tr loss: 0.6295 | vl loss: 0.951 | tr acc.: 0.5855 | vl acc.: 0.225 |
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch 2 | tr loss: 0.5487 | vl loss: 0.8851 | tr acc.: 0.7215 | vl acc.: 0.225 |
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch 3 | tr loss: 0.5097 | vl loss: 1.4344 | tr acc.: 0.75 | vl acc.: 0.225 |
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# epoch 4 | tr loss: 0.4638 | vl loss: 1.5777 | tr acc.: 0.7785 | vl acc.: 0.225 |
# ...

# %%
import matplotlib.pyplot as plt
import json

def model_plot(path):
    with open(path) as json_file:
        json_log = json.load(json_file)

    tr_loss = json_log["1"]["tr loss"]
    vl_loss = json_log["1"]["vl loss"]
    tr_acc = json_log["1"]["tr acc."]
    vl_acc = json_log["1"]["vl acc."]

    epochs = range(1, len(tr_loss) + 1)

    # Create subplots with a horizontal layout
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    
    # Plot training and validation losses
    ax1.plot(epochs, tr_loss, label="Training Loss")
    ax1.plot(epochs, vl_loss, label="Validation Loss")
    ax1.set_title("Training and Validation Loss")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")
    ax1.legend()

    # Plot training and validation accuracies
    ax2.plot(epochs, tr_acc, label="Training Accuracy")
    ax2.plot(epochs, vl_acc, label="Validation Accuracy")
    ax2.set_title("Training and Validation Accuracy")
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")
    ax2.legend()

    # Adjust spacing between subplots
    plt.tight_layout()

    # Display the plot
    plt.show()

# %%
model_plot(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\Images\trainning\saved_weights\3_2_64_ResNet 18_0.0001_10\3_2_64_ResNet 18_0.0001_10.json")
# overfitting

# %%
model_plot(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\Images\trainning\saved_weights\3_2_64_ResNet 18_1e-05_10\3_2_64_ResNet 18_1e-05_10.json")
# etwas besser, val loss runtergegangen, versuch mehr echos

# %%
model_plot(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\Images\trainning\saved_weights\3_2_64_ResNet 18_1e-05_20\3_2_64_ResNet 18_1e-05_20.json")
# mehr echos ändert sich nicht groß

# %%
model_plot(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\Images\trainning\saved_weights\3_2_64_ResNet 18_5e-06_50\3_2_64_ResNet 18_5e-06_50.json")
# kleiner learning rate mehr echos auch nicht so viel verändert

# %%
model_plot(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\Images\trainning\saved_weights\3_2_64_ResNet 18 dropout 0.2_0.0001_50\3_2_64_ResNet 18 dropout 0.2_0.0001_50.json")

# %%
model_plot(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\Images\trainning\saved_weights\3_2_64_ResNet 18 dropout 0.2_1e-05_50\3_2_64_ResNet 18 dropout 0.2_1e-05_50.json")

# %%
model_plot(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\Images\trainning\saved_weights\3_2_64_ResNet 18 dropout 0.5_0.0001_30\3_2_64_ResNet 18 dropout 0.5_0.0001_30.json")

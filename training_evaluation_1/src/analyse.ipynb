# %%
import json
import matplotlib.pyplot as plt

def load_json(json_filename):
    with open(json_filename, "r") as json_file:
        json_data = json.load(json_file)
    return json_data["log"]

# %%
denseNet121_log_4 = load_json("learning_path\denseNet121_0.0001_16_60_True_True_False_False.json")
denseNet121_log_5 = load_json("learning_path\denseNet121_1e-05_16_60_True_True_False_False.json")
denseNet121_log_6 = load_json("learning_path\denseNet121_1e-06_16_60_True_True_False_False.json")
denseNet121_log_7 = load_json("learning_path\denseNet121_1e-07_16_60_True_True_False_False.json")

val_accuracy_path = [
    denseNet121_log_4["val accuracy"],
    denseNet121_log_5["val accuracy"],
    denseNet121_log_6["val accuracy"],
    denseNet121_log_7["val accuracy"]
]

epoch = list(range(1, 61))
legend_labels = ["Lernrat 1e-4", "Lernrat 1e-5", "Lernrat 1e-6", "Lernrat 1e-7"]
plt.ylim(0.0, 1.0)

for i, data in enumerate(val_accuracy_path):
    plt.plot(epoch, data, label=legend_labels[i])

# plt.title("Lernverlauf von DenseNet121")
plt.xlabel("Epoch")
plt.ylabel("Genauigkeit")

plt.legend()
plt.show()

# %%
denseNet121_log_6 = load_json("learning_path\DenseNet121_1e-06_16_60_True_True_False_False.json")
denseNet161_log_6 = load_json("learning_path\DenseNet161_1e-06_8_60_True_True_False_False.json")
denseNet201_log_6 = load_json("learning_path\DenseNet201_1e-06_8_60_True_True_False_False.json")
ResNet34_log_6 = load_json("learning_path\ResNet34_1e-06_16_60_True_True_False_False.json")
ResNet50_log_6 = load_json("learning_path\ResNet50_1e-06_8_60_True_True_False_False.json")
AlexNet_log_6 = load_json("learning_path\AlexNet_1e-06_16_60_True_True_False_False.json")

val_accuracy_path = [
    denseNet121_log_6["val accuracy"],
    denseNet161_log_6["val accuracy"],
    denseNet201_log_6["val accuracy"],
    ResNet34_log_6["val accuracy"],
    ResNet50_log_6["val accuracy"],
    AlexNet_log_6["val accuracy"]
]

epoch = list(range(1, 61))
legend_labels = ["DenseNet121", "DenseNet161", "DenseNet201", "ResNet34", "ResNet50", "AlexNet"]
plt.ylim(0.5, 1.0)

for i, data in enumerate(val_accuracy_path):
    plt.plot(epoch, data, label=legend_labels[i])

# plt.title("Lernverlauf der verschiedene Modelle")
plt.xlabel("Epoch")
plt.ylabel("Genauigkeit")

plt.legend()
plt.show()

# %%
denseNet161_log_6 = load_json("learning_path\DenseNet161_1e-06_8_60_True_True_False_False.json")
denseNet201_log_6 = load_json("learning_path\DenseNet201_1e-06_8_60_True_True_False_False.json")

val_accuracy_path = [
    denseNet161_log_6["train accuracy"],
    denseNet201_log_6["train accuracy"],
    denseNet161_log_6["train loss"],
    denseNet201_log_6["train loss"],
]

epoch = list(range(1, 61))
legend_labels = ["Trainingsgenauigkeit DenseNet161", "Trainingsgenauigkeit DenseNet201", "Trainingsverlust DenseNet161", "Trainingsverlust DenseNet201"]
plt.ylim(0.0, 1.0)

for i, data in enumerate(val_accuracy_path):
    plt.plot(epoch, data, label=legend_labels[i])

plt.title("Trainingsverlauf der verschiedene Modelle")
plt.xlabel("Epoch")
plt.ylabel("Genauigkeit")

plt.legend()
plt.show()

# %%
denseNet121_log_4 = load_json("learning_path\denseNet121_0.0001_16_60_True_True_False_False.json")
denseNet121_log_5 = load_json("learning_path\denseNet121_1e-05_16_60_True_True_False_False.json")
denseNet121_log_6 = load_json("learning_path\denseNet121_1e-06_16_60_True_True_False_False.json")

val_accuracy_path = [
    denseNet121_log_4["val accuracy"],
    denseNet121_log_5["val accuracy"],
    denseNet121_log_6["val accuracy"],
]

epoch = list(range(1, 61))
legend_labels = ["Lernrat 1e-4", "Lernrat 1e-5", "Lernrat 1e-6"]
plt.ylim(0.5, 1.0)

for i, data in enumerate(val_accuracy_path):
    plt.plot(epoch, data, label=legend_labels[i])

plt.title("Lernverlauf von DenseNet121")
plt.xlabel("Epoch")
plt.ylabel("Genauigkeit")

plt.legend()
plt.show()

# %%
ResNet50_log_4 = load_json("learning_path\ResNet50_0.0001_8_30_True_True_False_False.json")
ResNet50_log_5 = load_json("learning_path\ResNet50_1e-05_8_30_True_True_False_False.json")
ResNet50_log_6 = load_json("learning_path\ResNet50_1e-06_8_30_True_True_False_False.json")

val_accuracy_path = [
    ResNet50_log_4["val accuracy"],
    ResNet50_log_5["val accuracy"],
    ResNet50_log_6["val accuracy"],
]

epoch = list(range(1, 31))
legend_labels = ["Lernrat 1e-4", "Lernrat 1e-5", "Lernrat 1e-6"]
plt.ylim(0.5, 1.0)

for i, data in enumerate(val_accuracy_path):
    plt.plot(epoch, data, label=legend_labels[i])

plt.title("Lernverlauf von ResNet50")
plt.xlabel("Epoch")
plt.ylabel("Genauigkeit")

plt.legend()
plt.show()

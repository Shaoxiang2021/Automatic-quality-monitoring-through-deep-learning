# %%
from PIL import Image
import numpy as np
from torchvision import transforms
img = Image.open(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\trainning_dense121\data\raw\test\0\5_001_500_1500_5_1.jpg")

img = np.array(img)/255

tsr = transforms.Compose([transforms.ToTensor(), transforms.RandomRotation(degrees=5), transforms.ColorJitter(brightness=(0.5, 1.5)), transforms.GaussianBlur((7, 7), sigma=(0.1, 0.5)), transforms.ToPILImage()])
img = tsr(img)
img
# Out:
# <PIL.Image.Image image mode=RGB size=752x160>

# %%
import torch
class AddNoiseToTensor(object):
    def __init__(self, p, alpha):
        """
        implements the __call__ method of a torchvision transform operation

        Args:
            p: probability with which the transform should be applied
            alpha: scaling factor for the normal distributed noise
        """
        self.p = p
        self.a = alpha

    def __call__(self, x):

        # tip: use pytorch for random operations, since it handles management of random seeds in
        # workers of dataloader correctly. Numpy for example doesn't, which results in identical samples
        if torch.rand(1) < self.p:
            # add noise from normal distribution to tensor with a given probability
            return x + torch.randn_like(x) * self.a
        return x

# %% [markdown]
# Augumentation

# %%
from torchvision import transforms
import torch

img = Image.open(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\trainning_dense121\data\raw\test\0\5_001_500_1500_5_1.jpg")

ts = transforms.GaussianBlur((7, 7), sigma=(0.1, 2))
img_rotate = ts(img)
img_rotate
# Out:
# <PIL.Image.Image image mode=RGB size=752x160>

# %%
import numpy as np

img_np = np.array(img)/255
img_np
# Out:
# array([[[0.43529412, 0.34509804, 0.29019608],
#         [0.41960784, 0.3254902 , 0.28627451],
#         [0.41568627, 0.32156863, 0.32156863],
#         ...,
#         [0.2745098 , 0.26666667, 0.27058824],
#         [0.28627451, 0.26666667, 0.28235294],
#         [0.2745098 , 0.25490196, 0.27058824]],
#
#        [[0.41176471, 0.34901961, 0.28627451],
#         [0.39215686, 0.34117647, 0.27843137],
#         [0.4       , 0.34117647, 0.32156863],
#         ...,
#         [0.26666667, 0.25098039, 0.25490196],
#         [0.2745098 , 0.25882353, 0.2627451 ],
#         [0.26666667, 0.24705882, 0.2627451 ]],
#
#        [[0.44705882, 0.4627451 , 0.36470588],
#         [0.44313725, 0.4627451 , 0.37254902],
#         [0.45098039, 0.46666667, 0.4       ],
#         ...,
#         [0.2627451 , 0.23921569, 0.23921569],
#         [0.27058824, 0.24705882, 0.25490196],
#         [0.26666667, 0.24313725, 0.25098039]],
#
#        ...,
#
#        [[0.41960784, 0.30980392, 0.2627451 ],
#         [0.42745098, 0.31764706, 0.27058824],
#         [0.42352941, 0.31372549, 0.27058824],
#         ...,
#         [0.20392157, 0.2       , 0.23137255],
#         [0.19607843, 0.18431373, 0.21960784],
#         [0.19215686, 0.18823529, 0.21176471]],
#
#        [[0.37254902, 0.27843137, 0.23137255],
#         [0.35686275, 0.2627451 , 0.22352941],
#         [0.34901961, 0.25098039, 0.23137255],
#         ...,
#         [0.20392157, 0.19215686, 0.23529412],
#         [0.19607843, 0.17254902, 0.21960784],
#         [0.19607843, 0.18431373, 0.21960784]],
#
#        [[0.3372549 , 0.25098039, 0.20784314],
#         [0.32941176, 0.23921569, 0.20784314],
#         [0.34901961, 0.25490196, 0.24705882],
#         ...,
#         [0.2       , 0.17647059, 0.22352941],
#         [0.18823529, 0.16470588, 0.21176471],
#         [0.20784314, 0.18431373, 0.23137255]]])

# %%
from PIL import Image

img_convert = Image.fromarray((img_np*255).astype(np.uint8))
img_convert
# Out:
# <PIL.Image.Image image mode=RGB size=752x160>

# %%
from torchvision import transforms
ts =transforms.RandomRotation(degrees=20) 
img_r = ts(img_convert)
img_r
# Out:
# <PIL.Image.Image image mode=RGB size=752x160>

# %%
img = Image.open(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\trainning_dense121\data\raw\test\0\5_001_500_1500_5_1.jpg")

# %%
ts = transforms.GaussianBlur((7, 7), sigma=(0.1, 0.5))
img_a = ts(img)
img_a
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
ts = transforms.RandomAutocontrast(p=1)
img_a = ts(img)
img_a
# Out:
# <PIL.Image.Image image mode=RGB size=752x160>

# %%
# torch.manual_seed(1)
ts = transforms.ColorJitter(brightness=(0.5, 1.5))
img_a = ts(img)
img_a
# Out:
# <PIL.Image.Image image mode=RGB size=752x160>

# %% [markdown]
# Random Seed

# %%
import numpy as np
import torch

np.random.seed(1)
print(np.random.randn(1))

np.random.seed(1)
print(np.random.randn(1))
# Out:
# [1.62434536]
# [1.62434536]

# %%
test_list = [6, 4, 8, 9, 10]
test_list.pop(2)
# Out:
# 8

# %%
test_list
# Out:
# [6, 4, 9, 10]

# %%
import random
test_list = [6, 4, 8, 9, 10]
random.seed(1)
for i in range(3):
    idx = random.randint(0, len(test_list)-1)
    test_list.pop(idx)
test_list
# Out:
# [8, 10]

# %%
from dataset import MyData
data_aug = MyData(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\trainning_dense121\data\processed\data.json", train=True, transform=None, aug=0.2)
data_aug.paths
# Out:
# ['../data/processed/train/0/5_001_500_1500_5_14.npy',
#  '../data/processed/train/0/5_001_500_1500_5_17.npy',
#  '../data/processed/train/0/5_001_500_1500_5_5.npy',
#  '../data/processed/train/0/5_002_500_1700_5_15.npy',
#  '../data/processed/train/0/5_003_500_1900_5_16.npy',
#  '../data/processed/train/0/5_019_600_2900_5_1.npy',
#  '../data/processed/train/0/5_024_700_1700_5_1.npy',
#  '../data/processed/train/0/5_024_700_1700_5_10.npy',
#  '../data/processed/train/0/5_024_700_1700_5_13.npy',
#  '../data/processed/train/0/5_024_700_1700_5_8.npy',
#  '../data/processed/train/0/5_027_700_2300_5_13.npy',
#  '../data/processed/train/0/5_027_700_2300_5_15.npy',
#  '../data/processed/train/1/5_023_700_1500_5_11.npy',
#  '../data/processed/train/1/5_023_700_1500_5_15.npy',
#  '../data/processed/train/1/5_023_700_1500_5_18.npy',
#  '../data/processed/train/1/5_023_700_1500_5_5.npy',
#  '../data/processed/train/1/5_023_700_1500_5_9.npy',
#  '../data/processed/train/1/5_024_700_1700_5_17.npy',
#  '../data/processed/train/1/5_025_1900_700_5_18.npy',
#  '../data/processed/train/1/5_025_1900_700_5_9.npy',
#  '../data/processed/train/1/5_027_700_2300_5_14.npy',
#  '../data/processed/train/1/5_029_700_2700_5_5.npy',
#  '../data/processed/train/1/5_030_700_2900_5_18.npy',
#  '../data/processed/train/1/5_030_700_2900_5_2.npy',
#  '../data/processed/train/1/5_030_700_2900_5_4.npy',
#  '../data/processed/train/1/5_031_700_3100_5_2.npy',
#  '../data/processed/train/1/5_032_700_3300_5_10.npy',
#  '../data/processed/train/1/5_032_700_3300_5_11.npy',
#  '../data/processed/train/1/5_032_700_3300_5_12.npy',
#  '../data/processed/train/1/5_033_700_3500_5_10.npy',
#  '../data/processed/train/1/5_033_700_3500_5_5.npy',
#  '../data/processed/train/1/5_033_700_3500_5_6.npy',
#  '../data/processed/train/1/5_051_900_2700_5_10.npy',
#  '../data/processed/train/1/5_051_900_2700_5_14.npy',
#  '../data/processed/train/1/5_051_900_2700_5_8.npy',
#  '../data/processed/train/1/5_054_900_3300_5_11.npy',
#  '../data/processed/train/1/5_058_1000_1900_5_1.npy',
#  '../data/processed/train/1/5_058_1000_1900_5_12.npy',
#  '../data/processed/train/1/5_063_1000_2900_5_4.npy',
#  '../data/processed/train/1/5_063_1000_2900_5_8.npy',
#  '../data/processed/train/1/5_076_1100_3300_5_15.npy',
#  '../data/processed/train/1/5_109_1400_3300_5_15.npy',
#  '../data/processed/train/1/None_500_1500_5_13.npy']

# %%
data = MyData(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\trainning_dense121\data\processed\data.json", train=True, transform=None)
len(data)
# Out:
# 456

# %%
total_data = data + data_aug
len(total_data)
# Out:
# 548

# %%
int(2.7)
# Out:
# 2

# %%
import random
random.seed(1)
random.randint(1, 3)
# Out:
# 1

# %%
random.seed(1)
for i in range(10):
    idx = random.randint(1, 3)
    print(idx)
# Out:
# 1
# 3
# 1
# 2
# 1
# 2
# 2
# 2
# 3
# 2

# %%
def f():
    idx = random.randint(1, 3)
    print(idx)

# %%
class Return(object):
     def __call__(self, x):
        return x*255

# %%
from PIL import Image
import torch
import numpy as np
from torchvision import transforms
img = Image.open(r"C:\Users\tsx10\PythonProjectsJupyter\TUM\FP\trainning_dense121\data\raw\test\0\5_001_500_1500_5_1.jpg")

img = np.array(img)
trans = transforms.ToPILImage()
img = trans(img)
img
# Out:
# <PIL.Image.Image image mode=RGB size=752x160>
